# %%
import cv2
import cv2
import cv2
import cv2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('images/penguin.jpg')
print(type(img1))
print(img1.shape)
# Out:
# <class 'numpy.ndarray'>
# (222, 296, 3)

# %%
plt.imshow(img1)
plt.show()

# %%
cv2.imshow("window", img1)
cv2.waitKey(2000)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imshow("window", img1)
cv2.waitKey(4000)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
img2 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.show()

# %%
cv2.imshow('frame', img2)
cv2.waitKey(3000)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
img3_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
print(img3_gray.shape)
plt.imshow(img3_gray, cmap='gray')
plt.show()
# Out:
# (222, 296)

# %%
cv2.imshow('frame_gray', img3_gray)
cv2.waitKey(3000)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
blue = img1[:,:,0]
green = img1[:,:,1]
red = img1[:,:,2]
print(blue.shape, green.shape, red.shape)
# Out:
# (222, 296) (222, 296) (222, 296)

# %%
plt.figure(figsize=(7,5))
plt.subplot(2,2,1)
plt.title('original', fontsize=20)
plt.imshow(img1[:,:,::-1])
plt.axis('off')

plt.subplot(2,2,2)
plt.title('Blue',fontsize=20)
plt.imshow(blue, cmap='gray')
plt.axis('off')

plt.subplot(2,2,3)
plt.title('Green',fontsize=20)
plt.imshow(green, cmap='gray')
plt.axis('off')

plt.subplot(2,2,4)
plt.title('Red',fontsize=20)
plt.imshow(red, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
img1 = cv2.imread('images/penguin.jpg')
img2 = cv2.imread('images/lenna.bmp')
img3 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
print(img1.shape, img2.shape, img3.shape)
print(img1.dtype, img2.dtype, img3.dtype)
# Out:
# (222, 296, 3) (512, 512, 3) (222, 296)
# uint8 uint8 uint8

# %%
##### 선생님 !!!!! 이거 오류남/...######
cv2.imshow('frame', img3)

#특정 문자를입력 받았을 때  꺼지도록 처리.
while True:
    if cv2.waitKey(0) == ord('q'):  # 특정 숫자 q 가 눌러지면 꺼지도록...
        break
  
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
cv2.imshow('frame', img3)

while True:
    if cv2.waitKey(0) == ord('q'):
        break
        
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
import 
cap=cv2.VideoCapture(0)
print(cap.isOpened())
while True:
    sucess, image = cap.read()
    if noe sucess:
        print('프레임을 읽어오지 못함')
        break
    
    cv2.imshow('frame', image)
    if cv2.waitKey(1) ==27:
        break
cv2.release()
cv2.destroyAllWindows()
cv2.wait()

# %%
cap = cv2.VideoCapture(0)
cnt = 0 
while True:
    
    sucess, image = cap.read()
    if not sucess:
        print('캡쳐 실패')
        break
        
    cv2.imshow('frame', immage)
    if cnt % 30 ==0:
        file_path = os.path.join(save_dir,f"cap_(cnt).jpg)
        cv2.imwite(file_path, image)
    cnt += 1
                                 
    if cv2.waitKey(1) ==27:
        break

cap.release
cv2.destroyAllWindows()
cv2,wait
