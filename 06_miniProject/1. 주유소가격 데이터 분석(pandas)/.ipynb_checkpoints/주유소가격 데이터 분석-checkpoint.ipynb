# %%
import matplotlib.pyplot as plt  # matplotlib 설치시 혹은 터미널 시작시, 1번과 2번, 3번 명령어 입력으로 폰트깨짐 해결.(Mac 한정.)
from matplotlib import rc        # 1번
rc('font', family='AppleGothic') # 2번
plt.rcParams['axes.unicode_minus'] = False #3번

# %% [markdown]
# kgmyh@naver.com 으로 `이름_주유소가격 데이터 분석.html` 로 제출
# - html 파일로 변환
#     - File > Download as > HTML (.html) 선택

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# - 2022년 주유소들의 일자별 가격 데이터
# - https://www.opinet.co.kr/user/opdown/opDownload.do

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 상반기, 하반기 주유소 가격 데이터 조회
# 상반기.
fh = pd.read_csv('data/2022년_서울_상반기_일별_가격.csv', encoding='cp949')
fh
# Out:
#              번호      지역                  상호                    주소        기간  \
# 0      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220101
# 1      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220102
# 2      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220103
# 3      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220104
# 4      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220105
# ...         ...     ...                 ...                   ...       ...
# 82684  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220507
# 82685  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220508
# 82686  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220509
# 82687  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220510
# 82688  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220511
#
#            상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0       SK에너지   셀프   1887  1737  1587     0
# 1       SK에너지   셀프   1887  1737  1587     0
# 2       SK에너지   셀프   1887  1737  1587     0
# 3       SK에너지   셀프   1887  1737  1587     0
# 4       SK에너지   셀프   1887  1737  1587     0
# ...       ...  ...    ...   ...   ...   ...
# 82684  현대오일뱅크   셀프   2152  1910  1841     0
# 82685  현대오일뱅크   셀프   2152  1910  1841     0
# 82686  현대오일뱅크   셀프   2152  1910  1841     0
# 82687  현대오일뱅크   셀프   2152  1910  1841     0
# 82688  현대오일뱅크   셀프   2152  1910  1841     0
#
# [82689 rows x 11 columns]

# %%
# 하반기
sh = pd.read_csv('data/2022년_서울_하반기_일별_가격.csv', encoding='cp949')
sh
# Out:
#              번호      지역               상호                       주소        기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220701
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220702
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220703
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220704
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220705
# ...         ...     ...              ...                      ...       ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0      SK에너지   셀프   2487  2287  2297     0
# 1      SK에너지   셀프   2447  2247  2277     0
# 2      SK에너지   셀프   2447  2247  2277     0
# 3      SK에너지   셀프   2447  2247  2277     0
# 4      SK에너지   셀프   2447  2247  2277     0
# ...      ...  ...    ...   ...   ...   ...
# 81788  GS칼텍스   셀프      0  1525  1745     0
# 81789  GS칼텍스   셀프      0  1525  1720     0
# 81790  GS칼텍스   셀프      0  1525  1720     0
# 81791  GS칼텍스   셀프      0  1515  1715     0
# 81792  GS칼텍스   셀프      0  1515  1715     0
#
# [81793 rows x 11 columns]

# %%
# 상반기, 하반기 DataFrame 합치기
df = pd.concat([fh, sh])
df
# Out:
#              번호      지역               상호                       주소        기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105
# ...         ...     ...              ...                      ...       ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0      SK에너지   셀프   1887  1737  1587     0
# 1      SK에너지   셀프   1887  1737  1587     0
# 2      SK에너지   셀프   1887  1737  1587     0
# 3      SK에너지   셀프   1887  1737  1587     0
# 4      SK에너지   셀프   1887  1737  1587     0
# ...      ...  ...    ...   ...   ...   ...
# 81788  GS칼텍스   셀프      0  1525  1745     0
# 81789  GS칼텍스   셀프      0  1525  1720     0
# 81790  GS칼텍스   셀프      0  1525  1720     0
# 81791  GS칼텍스   셀프      0  1515  1715     0
# 81792  GS칼텍스   셀프      0  1515  1715     0
#
# [164482 rows x 11 columns]

# %%
# DataFrame 기본 정보 조회
df.shape
# Out:
# (164482, 11)

# %%
df.info
# Out:
# <bound method DataFrame.info of              번호      지역               상호                       주소        기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105
# ...         ...     ...              ...                      ...       ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0      SK에너지   셀프   1887  1737  1587     0
# 1      SK에너지   셀프   1887  1737  1587     0
# 2      SK에너지   셀프   1887  1737  1587     0
# 3      SK에너지   셀프   1887  1737  1587     0
# 4      SK에너지   셀프   1887  1737  1587     0
# ...      ...  ...    ...   ...   ...   ...
# 81788  GS칼텍스   셀프      0  1525  1745     0
# 81789  GS칼텍스   셀프      0  1525  1720     0
# 81790  GS칼텍스   셀프      0  1525  1720     0
# 81791  GS칼텍스   셀프      0  1515  1715     0
# 81792  GS칼텍스   셀프      0  1515  1715     0
#
# [164482 rows x 11 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164482 entries, 0 to 81792
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      164482 non-null  object
#  1   지역      164482 non-null  object
#  2   상호      164482 non-null  object
#  3   주소      164482 non-null  object
#  4   기간      164482 non-null  int64
#  5   상표      164482 non-null  object
#  6   셀프여부    164482 non-null  object
#  7   고급휘발유   164482 non-null  int64
#  8   휘발유     164482 non-null  int64
#  9   경유      164482 non-null  int64
#  10  실내등유    164482 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 15.1+ MB

# %%
# 상표 컬럼의 고유값 조회
df['상표'].value_counts()
# Out:
# SK에너지     48267
# 현대오일뱅크    42351
# GS칼텍스     40449
# S-OIL     28762
# 알뜰주유소      3551
# 자가상표        737
# 알뜰(ex)      365
# Name: 상표, dtype: int64

# %%
# 지역 컬럼의 고유값 조회
df['지역'].value_counts()
# Out:
# 서울 강남구     12278
# 서울 강서구     11825
# 서울 송파구     11295
# 서울 서초구     11231
# 서울 영등포구     9814
# 서울 양천구      9015
# 서울 성북구      8522
# 서울 구로구      7384
# 서울 동대문구     6574
# 서울 성동구      6006
# 서울 도봉구      5992
# 서울 은평구      5807
# 서울 노원구      5474
# 서울 서대문구     5472
# 서울 강동구      5110
# 서울 광진구      5107
# 서울 관악구      5104
# 서울 중랑구      4873
# 서울 용산구      4637
# 서울 강북구      4460
# 서울 마포구      4375
# 서울 금천구      4067
# 서울 중구       3643
# 서울 동작구      3436
# 서울 종로구      2981
# Name: 지역, dtype: int64

# %% [markdown]
# > ### str accessor
# > - `Series.str.String메소드()`
# > - 문자열 타입 Series에 String 메소드들을 사용하여 일괄처리 할 수 있도록 한다.
# > - str accessor 메소드 : https://pandas.pydata.org/pandas-docs/stable/reference/series.html#api-series-str
#
# > ### datetime으로 변환
# > - `pd.to_datetime(변환할 Series, format="날짜형식")`
# > - x 또는 y 축이 날짜 일 경우 datetime 타입으로 처리하는 것이 좋다.
# > - format: 년월일의 형식을 strftime 형식문자열로 지정한다.
# >      - [strftime 형식](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes)
# > - datetime을 변환하면 날짜만의 기능을 다룰 수 있다.
# >     - dt accessor를 이용해 datetime의 속성값들을(년, 월, 일 등) 추출할 수 있다.
# >     - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html

# %%
# 지역 컬럼의 값을 이용하여 "구" 컬럼 생성 (지역에서 구만 추출해서 파생변수컬럼 생성)

def split_data(df):
    지역구 = df.split("울")[1].split(" ")[1]
    return 지역구

df["지역구"] = df["지역"].apply(split_data)

# %%
df
# Out:
#              번호      지역               상호                       주소        기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105
# ...         ...     ...              ...                      ...       ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유  지역구
# 0      SK에너지   셀프   1887  1737  1587     0  강남구
# 1      SK에너지   셀프   1887  1737  1587     0  강남구
# 2      SK에너지   셀프   1887  1737  1587     0  강남구
# 3      SK에너지   셀프   1887  1737  1587     0  강남구
# 4      SK에너지   셀프   1887  1737  1587     0  강남구
# ...      ...  ...    ...   ...   ...   ...  ...
# 81788  GS칼텍스   셀프      0  1525  1745     0  중랑구
# 81789  GS칼텍스   셀프      0  1525  1720     0  중랑구
# 81790  GS칼텍스   셀프      0  1525  1720     0  중랑구
# 81791  GS칼텍스   셀프      0  1515  1715     0  중랑구
# 81792  GS칼텍스   셀프      0  1515  1715     0  중랑구
#
# [164482 rows x 12 columns]

# %%
# 기간 컬럼을 datetime 타입으로 변경
df['기간'] = df['기간'].astype('str')
df['기간'] = pd.to_datetime(df['기간'])
df
# Out:
#              번호      지역               상호                       주소         기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-01
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-02
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-03
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-04
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-05
# ...         ...     ...              ...                      ...        ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-27
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-28
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-29
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-30
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-31
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유  지역구
# 0      SK에너지   셀프   1887  1737  1587     0  강남구
# 1      SK에너지   셀프   1887  1737  1587     0  강남구
# 2      SK에너지   셀프   1887  1737  1587     0  강남구
# 3      SK에너지   셀프   1887  1737  1587     0  강남구
# 4      SK에너지   셀프   1887  1737  1587     0  강남구
# ...      ...  ...    ...   ...   ...   ...  ...
# 81788  GS칼텍스   셀프      0  1525  1745     0  중랑구
# 81789  GS칼텍스   셀프      0  1525  1720     0  중랑구
# 81790  GS칼텍스   셀프      0  1525  1720     0  중랑구
# 81791  GS칼텍스   셀프      0  1515  1715     0  중랑구
# 81792  GS칼텍스   셀프      0  1515  1715     0  중랑구
#
# [164482 rows x 12 columns]

# %%
# 기간 컬럼을 이용해 "월", "일", "요일" 컬럼 생성 (dt accessor 이용)
# object 타입을 datetime64[ns] 타입으로 바꾼다 
df['기간'] = pd.to_datetime(df['기간'], format='%Y-%m-%d', errors='raise')

# %%
df['기간_년도']       = df['기간'].dt.year         # 연(4자리숫자)
df['기간_월']      = df['기간'].dt.month        # 월(숫자)
df['기간_일']        = df['기간'].dt.day          # 일(숫자)
df
# Out:
#              번호      지역               상호                       주소         기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-01
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-02
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-03
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-04
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-05
# ...         ...     ...              ...                      ...        ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-27
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-28
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-29
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-30
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-31
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유  지역구  기간_년도  기간_월  기간_일
# 0      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     1
# 1      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     2
# 2      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     3
# 3      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     4
# 4      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     5
# ...      ...  ...    ...   ...   ...   ...  ...    ...   ...   ...
# 81788  GS칼텍스   셀프      0  1525  1745     0  중랑구   2022    12    27
# 81789  GS칼텍스   셀프      0  1525  1720     0  중랑구   2022    12    28
# 81790  GS칼텍스   셀프      0  1525  1720     0  중랑구   2022    12    29
# 81791  GS칼텍스   셀프      0  1515  1715     0  중랑구   2022    12    30
# 81792  GS칼텍스   셀프      0  1515  1715     0  중랑구   2022    12    31
#
# [164482 rows x 15 columns]

# %%
# 요일 - 0:월, 1:화, 2:수, 3:목, 4:금, 5:토, 6:일 로 변경

# 0~6번 인덱스 위치에 각 한글 요일 이름이 담긴 리스트
weekday_list = ['0-월', '1-화', '2-수', '3-목', '4-금', '5-토', '6-일']

# apply 함수로 숫자 -> 요일 이름으로 변환
df['요일'] = df.apply(lambda x : weekday_list[x['요일숫자']], axis = 1)
df
# Out:
#              번호      지역               상호                       주소         기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-01
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-02
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-03
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-04
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-05
# ...         ...     ...              ...                      ...        ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-27
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-28
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-29
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-30
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-31
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유  지역구  기간_년도  기간_월  기간_일  요일숫자   요일
# 0      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     1     5  5-토
# 1      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     2     6  6-일
# 2      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     3     0  0-월
# 3      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     4     1  1-화
# 4      SK에너지   셀프   1887  1737  1587     0  강남구   2022     1     5     2  2-수
# ...      ...  ...    ...   ...   ...   ...  ...    ...   ...   ...   ...  ...
# 81788  GS칼텍스   셀프      0  1525  1745     0  중랑구   2022    12    27     1  1-화
# 81789  GS칼텍스   셀프      0  1525  1720     0  중랑구   2022    12    28     2  2-수
# 81790  GS칼텍스   셀프      0  1525  1720     0  중랑구   2022    12    29     3  3-목
# 81791  GS칼텍스   셀프      0  1515  1715     0  중랑구   2022    12    30     4  4-금
# 81792  GS칼텍스   셀프      0  1515  1715     0  중랑구   2022    12    31     5  5-토
#
# [164482 rows x 17 columns]

# %%
# 휘발유 가격이 가장 비싼 5개 행 조회
# df['휘발유'].agg(["max"])

# df['휘발유'].sort_values(ascending=False).head(5)

df.sort_values('휘발유').tail(5)
# Out:
#              번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 78937  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-24  SK에너지   일반   3496
# 78938  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-25  SK에너지   일반   3496
# 78939  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-26  SK에너지   일반   3496
# 78940  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-27  SK에너지   일반   3496
# 78935  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-22  SK에너지   일반   3496
#
#         휘발유    경유  실내등유 지역구  기간_년도  기간_월  기간_일  요일숫자   요일
# 78937  3096  3223  2719  중구   2022     6    24     4  4-금
# 78938  3096  3223  2719  중구   2022     6    25     5  5-토
# 78939  3096  3223  2719  중구   2022     6    26     6  6-일
# 78940  3096  3223  2719  중구   2022     6    27     0  0-월
# 78935  3096  3223  2719  중구   2022     6    22     2  2-수

# %%
# 휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
# result = df['휘발유'].sort_values().tail(5)
# result[result != 0].sort_values(ascending=False) 

df[df['휘발유'] != 0].sort_values('휘발유').head()
# Out:
#              번호      지역               상호                      주소         기간  \
# 16809  A0000519  서울 강서구           화곡역주유소    서울 강서구 강서로 154 (화곡동) 2022-12-27
# 15150  A0000549  서울 강서구  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동) 2022-12-24
# 15151  A0000549  서울 강서구  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동) 2022-12-25
# 65744  A0001005  서울 양천구            현대주유소  서울 양천구 남부순환로 372 (신월동) 2022-12-26
# 15149  A0000549  서울 강서구  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동) 2022-12-23
#
#            상표 셀프여부  고급휘발유   휘발유    경유  실내등유  지역구  기간_년도  기간_월  기간_일  요일숫자   요일
# 16809   알뜰주유소   셀프      0  1410  1660     0  강서구   2022    12    27     1  1-화
# 15150  현대오일뱅크   셀프      0  1410  1660     0  강서구   2022    12    24     5  5-토
# 15151  현대오일뱅크   셀프      0  1410  1660     0  강서구   2022    12    25     6  6-일
# 65744   S-OIL   셀프      0  1410  1660     0  양천구   2022    12    26     0  0-월
# 15149  현대오일뱅크   셀프      0  1410  1660     0  강서구   2022    12    23     4  4-금

# %%
# 고급휘발유 가격이 가장 비싼 5개 행 조회
df.sort_values('고급휘발유').tail(5)
# Out:
#              번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 78939  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-26  SK에너지   일반   3496
# 78938  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-25  SK에너지   일반   3496
# 78936  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-23  SK에너지   일반   3496
# 78935  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-22  SK에너지   일반   3496
# 78937  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-24  SK에너지   일반   3496
#
#         휘발유    경유  실내등유 지역구  기간_년도  기간_월  기간_일  요일숫자   요일
# 78939  3096  3223  2719  중구   2022     6    26     6  6-일
# 78938  3096  3223  2719  중구   2022     6    25     5  5-토
# 78936  3096  3223  2719  중구   2022     6    23     3  3-목
# 78935  3096  3223  2719  중구   2022     6    22     2  2-수
# 78937  3096  3223  2719  중구   2022     6    24     4  4-금

# %%
# 고급휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
df[df['고급휘발유'] != 0].sort_values('고급휘발유').head()
# Out:
#              번호      지역       상호                       주소         기간     상표  \
# 15882  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-20  S-OIL
# 15883  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-21  S-OIL
# 15884  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-22  S-OIL
# 15885  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-23  S-OIL
# 15886  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-24  S-OIL
#
#       셀프여부  고급휘발유   휘발유    경유  실내등유  지역구  기간_년도  기간_월  기간_일  요일숫자   요일
# 15882   셀프   1599  1527  1787     0  강서구   2022    12    20     1  1-화
# 15883   셀프   1599  1499  1759     0  강서구   2022    12    21     2  2-수
# 15884   셀프   1599  1499  1759     0  강서구   2022    12    22     3  3-목
# 15885   셀프   1599  1499  1729     0  강서구   2022    12    23     4  4-금
# 15886   셀프   1599  1499  1729     0  강서구   2022    12    24     5  5-토

# %%
# 경유 가격이 가장 비싼 5개 행 조회
df.sort_values('경유').tail(5)
# Out:
#              번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 77932  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-07-04  SK에너지   일반   3481
# 77931  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-07-03  SK에너지   일반   3481
# 77930  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-07-02  SK에너지   일반   3481
# 78943  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-30  SK에너지   일반   3481
# 78941  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-28  SK에너지   일반   3481
#
#         휘발유    경유  실내등유 지역구  기간_년도  기간_월  기간_일  요일숫자   요일
# 77932  3081  3230  2703  중구   2022     7     4     0  0-월
# 77931  3081  3230  2703  중구   2022     7     3     6  6-일
# 77930  3081  3230  2703  중구   2022     7     2     5  5-토
# 78943  3081  3230  2703  중구   2022     6    30     3  3-목
# 78941  3081  3230  2703  중구   2022     6    28     1  1-화

# %%
# 경유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
df[df['경유'] != 0].sort_values('경유').head()
# Out:
#              번호      지역        상호                     주소         기간      상표  \
# 45209  A0011826  서울 서초구  만남의광장주유소   서울 서초구 양재대로12길 73-71 2022-01-16  알뜰(ex)
# 12343  A0004657  서울 강서구    뉴신정주유소  서울 강서구 곰달래로 207 (화곡동) 2022-01-11   알뜰주유소
# 12344  A0004657  서울 강서구    뉴신정주유소  서울 강서구 곰달래로 207 (화곡동) 2022-01-12   알뜰주유소
# 12345  A0004657  서울 강서구    뉴신정주유소  서울 강서구 곰달래로 207 (화곡동) 2022-01-13   알뜰주유소
# 16318  A0000519  서울 강서구    화곡역주유소   서울 강서구 강서로 154 (화곡동) 2022-01-06   알뜰주유소
#
#       셀프여부  고급휘발유   휘발유    경유  실내등유  지역구  기간_년도  기간_월  기간_일  요일숫자   요일
# 45209   셀프      0  1565  1367     0  서초구   2022     1    16     6  6-일
# 12343   일반      0  1547  1377     0  강서구   2022     1    11     1  1-화
# 12344   일반      0  1547  1377     0  강서구   2022     1    12     2  2-수
# 12345   일반      0  1547  1377     0  강서구   2022     1    13     3  3-목
# 16318   셀프      0  1547  1377     0  강서구   2022     1     6     3  3-목

# %%
# 상표별 휘발유 평균가격 조회
ave_price = df.groupby('상표')['휘발유'].mean().sort_values()
ave_price
# Out:
# 상표
# 알뜰(ex)    1759.884932
# 알뜰주유소     1767.914672
# 자가상표      1823.622795
# 현대오일뱅크    1839.447215
# S-OIL     1859.282595
# GS칼텍스     1904.899429
# SK에너지     1908.900823
# Name: 휘발유, dtype: float64

# %%
# 상표별 휘발유 평균가격 시각화
# plt.bar(ave_price.index, ave_price)

ave_price.plot(kind='barh', title='상표별 휘발유 평균가격', xlabel='Brand', ylabel='평균가격', 
              figsize=(10,5), rot=45)
# Out:
# <AxesSubplot:title={'center':'상표별 휘발유 평균가격'}, ylabel='Brand'>

# %%
# 셀프주유소와 일반주유소 개수 확인
# Out:
# 셀프여부  번호        지역      상호               주소                    기간          상표     고급휘발유  휘발유   경유    실내등유  지역구  기간_년도  기간_월  기간_일  요일숫자  요일
# 셀프    A0000011  서울 양천구  지에스이앤알 직영 서울주유소  서울 양천구 신정로 236 (신정동)  2022-01-01  GS칼텍스  0      1585  1415  0     양천구  2022   1     1     5     5-토    1
#       A0033131  서울 은평구  뉴타운셀프주유소         서울 은평구 통일로 1031       2022-04-16  S-OIL  0      2005  1945  0     은평구  2022   4     16    5     5-토    1
#                                                                2022-02-17  S-OIL  0      1735  1575  0     은평구  2022   2     17    3     3-목    1
#                                                                2022-02-18  S-OIL  0      1735  1575  0     은평구  2022   2     18    4     4-금    1
#                                                                2022-02-19  S-OIL  0      1735  1575  0     은평구  2022   2     19    5     5-토    1
#                                                                                                                                                ..
# 일반    A0009220  서울 중랑구  범아주유소            서울 중랑구 동일로 881 (묵동)   2022-04-23  S-OIL  0      1999  1919  1500  중랑구  2022   4     23    5     5-토    1
#                                                                2022-04-24  S-OIL  0      1999  1919  1500  중랑구  2022   4     24    6     6-일    1
#                                                                2022-04-25  S-OIL  0      1999  1919  1500  중랑구  2022   4     25    0     0-월    1
#                                                                2022-04-26  S-OIL  0      1999  1919  1500  중랑구  2022   4     26    1     1-화    1
#       A0032710  서울 구로구  시몬주유소            서울 구로구 부일로 871        2022-07-27  S-OIL  0      2137  0     0     구로구  2022   7     27    2     2-수    1
# Length: 164482, dtype: int64

# %%
# 셀프 여부에 따른 휘발유 평균 가격 비교 
df['셀프여부'].value_counts()
# Out:
# 셀프    92478
# 일반    72004
# Name: 셀프여부, dtype: int64

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교
ave_price2 =df.groupby(['상표','셀프여부'])['휘발유'].mean()
ave_price2
# Out:
# 상표      셀프여부
# GS칼텍스   셀프      1825.849350
#         일반      2001.420217
# S-OIL   셀프      1820.122748
#         일반      1932.115939
# SK에너지   셀프      1826.717027
#         일반      2003.229520
# 알뜰(ex)  셀프      1759.884932
# 알뜰주유소   셀프      1754.261378
#         일반      1796.201557
# 자가상표    셀프      2017.000000
#         일반      1821.768493
# 현대오일뱅크  셀프      1807.265898
#         일반      1877.606059
# Name: 휘발유, dtype: float64

# %%
# # 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교 시각화
# ave_price2.plot(kind='bar', title='상표별 휘발유 평균가격', xlabel='Brand', ylabel='평균가격', 
#               figsize=(15,5), rot=45)


ave_price2.plot(kind='bar', title='상표별 일반/셀프 ',xlabel='주유소', ylabel='평균가격'
               ,figsize=(15,5), rot=45)
plt.show()

# %%
# 상표별 휘발유 가격의 분포를 boxplot으로 시각화
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(1, 1, 1)

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격에 대한 분포 확인 - boxplot으로 시각화
plt.subplot(1,1,1)
sns.boxplot(x='상표',y='휘발유', data=df)
# Out:
# <AxesSubplot:xlabel='상표', ylabel='휘발유'>

# %%
# 구별 휘발유 가격의 평균
ave_region = df.groupby('지역구')['휘발유'].mean().sort_values()
ave_region
# Out:
# 지역구
# 강북구     1787.319507
# 금천구     1799.263339
# 양천구     1799.875541
# 도봉구     1800.197597
# 성북구     1805.115935
# 중랑구     1805.788631
# 광진구     1818.287644
# 서대문구    1818.858735
# 은평구     1821.937317
# 동대문구    1825.329176
# 강서구     1829.297928
# 동작구     1836.980792
# 송파구     1843.436830
# 노원구     1845.411765
# 관악구     1851.051724
# 영등포구    1863.848380
# 구로구     1864.676733
# 마포구     1880.027429
# 서초구     1902.345027
# 강동구     1910.691977
# 성동구     1923.009324
# 강남구     2024.210946
# 종로구     2129.215029
# 중구      2149.957178
# 용산구     2203.392495
# Name: 휘발유, dtype: float64

# %%
# 평균 가격이 가장 높은 구의 상표별 휘발유 평균가격
# 용산구, 상표별 휘발유 평균가격
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/jf/l3x8dj6n62s041cwvf169t5w0000gn/T/ipykernel_1896/1315582325.py in <module>
#       2 # 용산구, 상표별 휘발유 평균가격
#       3 result3 = df.groupby(['지역구','상표'])['휘발유'].mean()
# ----> 4 result3.query()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'query'

# %%
# 월 평균 휘발유 가격
df.groupby('기간_월')['휘발유'].mean()
# Out:
# 기간_월
# 1     1704.975625
# 2     1781.803959
# 3     2007.941288
# 4     2030.140766
# 5     2027.255552
# 6     2151.490272
# 7     2082.667822
# 8     1858.737602
# 9     1799.546203
# 10    1737.285143
# 11    1715.447874
# 12    1627.068857
# Name: 휘발유, dtype: float64

# %%
# 각 구의 월별 평균 휘발유 가격 
dr = df.groupby(['기간_월','지역구'])['휘발유'].mean()
# Out:
# 기간_월  지역구
# 1     강남구    1845.037951
#       강동구    1732.289294
#       강북구    1599.384615
#       강서구    1657.352823
#       관악구    1693.370370
#                 ...
# 12    용산구    1996.453521
#       은평구    1592.550538
#       종로구    1966.540323
#       중구     1922.916129
#       중랑구    1566.585608
# Name: 휘발유, Length: 300, dtype: float64

# %%
# 각 구의 월별 평균가격의 변화추이 시각화
sns.lineplot(data=df)
plt.show()

# %%
# 가장 휘발유가격이 비싼 주유소 상위 5 - (같은 주유소가 여러개 나오므로 가장 비싼 가격을 기준으로 집계)

# %%
# 가장 휘발유가격이 저렴한 주유소 상위 5 - (같은 주유소가 여러개 나오므로 가장 비싼 가격을 기준으로 집계)

# %%
# 휘발유 비싼 주유소의 상위 5개의 상호, 지역, 주소 조회(중복제거-drop_duplicates)

# %%
# 휘발유 저렴한 주유소의 상위 5개의 상호, 지역, 주소 조회(중복제거)

# %%
# 고급 휘발유를 가장 많이 파는 구 조회

# %%
###############################################################################
# 주유소 가격 데이터를 이용해서 알고 싶은 정보들을 추가 분석해 보세요.
###############################################################################
